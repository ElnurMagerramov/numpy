# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

cars = pd.read_excel(
    "cars.xlsx"
)
sns.boxplot(x=cars.classes, y=cars.displ)
plt.show()

# %%
sns.violinplot(x=cars.classes, y=cars.displ)
plt.show()
